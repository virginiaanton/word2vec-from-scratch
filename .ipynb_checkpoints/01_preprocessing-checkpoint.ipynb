# %% [markdown]
# # <font color="blue">**WORD2VEC VARIANT USING NUMPY**</font>
# ## Author: Virginia Antón Yuste
#
# **Task Description**: Implement the core training loop of word2vec in pure NumPy (no PyTorch / TensorFlow or other ML frameworks). The applicant is free to choose any suitable text dataset. The task is to implement the optimization procedure (forward pass, loss, gradients, and parameter updates) for a standard word2vec variant (e.g. skip-gram with negative sampling or CBOW).

# %% [markdown]
# This project uses the *Bedtime Stories* dataset available on Hugging Face. The dataset contains a collection of short bedtime stories written in English, written for children. Each entry includes a full narrative text with simple vocabulary and clear sentence structures.

# %%
import numpy as np
import pandas as pd
import re
import pickle # to save and load the model
import os # to join the path
import random # for randomly generated numbers
import time # to record time for the report
import matplotlib # to plot the loss of experiments for the report

# %%
df = pd.read_csv("hf://datasets/gofilipa/bedtime_stories/stories.csv")

# %%
df.head()
# Out:
#                                              stories
# 0  The stars twinkled in the night sky as little ...
# 1  Once upon a time there was a little girl named...
# 2  Alice was so excited for her first sleepover a...
# 3  Once upon a time, there lived two best friends...
# 4  Max loved the stars. Every night he would lay ...

# %%
df.shape
# Out:
# (199, 1)

# %% [markdown]
# ## 1. DATA PREPARATION

# %% [markdown]
# As it is a DataFrame and we want to work with plain text we have to first convert it.

# %%
corpus = " ".join(df["stories"].astype(str))

# %%
print(corpus)
# Out:
# The stars twinkled in the night sky as little Eva lay in her bed dreaming of adventures. She imagined flying on the back of a dragon across the clouds, soaring over the tallest mountains. Just then, Eva heard a gentle whisper that seemed to come from everywhere. It said, "It's time for beddy-byes now, dream sweetly little one." Eva smiled and snuggled into her cozy blankets, dreaming of more magical places. Once upon a time there was a little girl named Sam. Every night she snuggled into her warm bed for a cozy sleep. One night, while snuggling with her teddy bear, Sam heard a gentle voice coming from the window. She got up to investigate and saw a soft, glowing light outside. It was a fairy with a big smile who asked Sam to join her on a magical adventure. They flew around the night sky, visiting different planets and galaxies. When the sun began to rise they returned back to Sam's window. The magical fairy gave Sam a hug and Sam went back to bed filled with wonderful memories. Alice was so excited for her first sleepover at her best friend's house. After playing all night and eating delicious snacks, they both got into their pajamas and laid down in the bed. They discussed all their favorite stories until their eyes got heavy and they both drifted off to dreamland while the stars shimmered above them. As they slowly fell asleep, Alice and her friend were filled with joy knowing they'd have more adventures to come. Once upon a time, there lived two best friends, a squirrel and a rabbit. Every day they spent playing together in the meadow, chasing each other around the tall grass and laughing with glee. At night, they snuggled together in a cozy nook of a tree, dreaming about their next adventure. One night, when the stars shone like little diamonds in the sky, they heard a magical song from a mysterious musician. As they followed the music, they discovered a small pond, full of fireflies that lit up the water and filled the air with even more wondrous tunes. From that day forward, every night before bed, they’d sit by the pond and listen to the enchanting song, until their Max loved the stars. Every night he would lay in bed and count each and every one. One night, he wished on the brightest star. When the morning came, a surprise was waiting for him at his doorstep! Max opened the package to find a jar of stars – millions of them! He now had all the stars he ever wanted! Once upon a time there was a magical world full of amazing creatures. Every night, before bed, two brave bunnies would explore the glowing world. On their adventures they would meet kind dragons, friendly sea horses, and singing birds. After their journey, the bunnies would curl up in their cozy nests for a peaceful slumber. Every night the bunnies would embark on a new, exciting adventure and drift off to sleep with sweet dreams of all the magical friends they'd made. Once upon a time there was a little bunny named Ben. Every evening his mommy tucked him in, kissed his forehead, and told him a bedtime story. Ben loved stories about princesses and dashing knights, but his favorite was one about a magical forest filled with friendly animals. That night, Ben followed a sparkly path to the forest and met a family of hares, a wise old owl, and a chirping group of birds. They all sang him a sweet lullaby and the little bunny drifted off to sleep. He woke up to his mommy's voice telling him it was time for bed. For Ben, it had been the best dream ever. Once upon a time, there was a rabbit named Jack. He loved to jump and play all night long. Just before bed, he'd meet his friends for a snack. They'd gather around a tree, and nibble and chat until the sun went down. As they said goodnight, Jack hopped home and into bed. He snuggled up under the covers, closed his eyes, and drifted off into a peaceful sleep. Sweet dreams were had by all, including Jack. Once upon a time there was a little boy named Tom who loved to explore the world. Every night he would go on an ad ...

# %% [markdown]
# Then we tokenize the data in order to feed our model. The first step, when it comes to NLP tasks, is to tokenize the text (divide in small units, such as words). In this step we are also going to remove the punctuations ansd so on.

# %%
def tokenize(text):
    text=text.lower()
    tokens= re.findall(r'[a-zA-Z]+[\w^\']*|[a-zA-Z]+[\w^\']*', text)
    return tokens

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# al tokenizar, filtrar las stopwords
tokens= tokenize(corpus)
tokens = [w for w in tokens if w not in stop_words]

print(tokens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       2 stop_words = set(stopwords.words('english'))
#       4 # al tokenizar, filtrar las stopwords
# ----> 5 tokens = [w for w in tokens if w not in stop_words]
#       6 tokens= tokenize(corpus)
#       7 print(tokens)
#
# NameError: name 'tokens' is not defined

# %% [markdown]
# Let's see how many words in total do we have.

# %%
len(tokens)
# Out:
# 17580

# %% [markdown]
# For this task I keep the words forms and the stopwords.

# %% [markdown]
# Now we are going to map between tokens and indices, and viceversa. For vector representation.

# %%
def mapTokens(tks):
    wordToId= {}
    idToWord = {}
    for idx, token in enumerate(set(tks)):
        wordToId[token] = idx
        idToWord[idx]=token
    return wordToId, idToWord

# %%
wordToId, idToWord = mapTokens(tokens)
wordToId
# Out:
# {'begun': 0,
#  'wild': 1,
#  'lion': 2,
#  'midnight': 3,
#  'afraid': 4,
#  'spread': 5,
#  'counting': 6,
#  'snacks': 7,
#  'favorite': 8,
#  'first': 9,
#  'circles': 10,
#  'faces': 11,
#  'luck': 12,
#  'million': 13,
#  'wolf': 14,
#  'nose': 15,
#  'hugged': 16,
#  'ate': 17,
#  'celebrated': 18,
#  'maybe': 19,
#  'knock': 20,
#  'cookies': 21,
#  'flickering': 22,
#  'these': 23,
#  'grandma': 24,
#  'behind': 25,
#  'lily': 26,
#  'too': 27,
#  'snooze': 28,
#  'wakes': 29,
#  'wondrous': 30,
#  'incredible': 31,
#  'let': 32,
#  'hot': 33,
#  'travel': 34,
#  'loyal': 35,
#  'flock': 36,
#  'cautiously': 37,
#  'predators': 38,
#  'sparkle': 39,
#  'straw': 40,
#  'crown': 41,
#  'anna': 42,
#  'zara': 43,
#  'hands': 44,
#  'left': 45,
#  "another's": 46,
#  'life': 47,
#  'sailed': 48,
#  'showered': 49,
#  'laid': 50,
#  'huddle': 51,
#  'discovered': 52,
#  'dazzling': 53,
#  'softly': 54,
#  'shot': 55,
#  'scary': 56,
#  'ellen': 57,
#  'also': 58,
#  'loved': 59,
#  'washing': 60,
#  'together': 61,
#  'summer': 62,
#  'friendly': 63,
#  'outdoors': 64,
#  'admiring': 65,
#  'weekend': 66,
#  'bedroom': 67,
#  "sophie's": 68,
#  'colors': 69,
#  'green': 70,
#  'papa': 71,
#  'people': 72,
#  'sticks': 73,
#  'pretend': 74,
#  'respective': 75,
#  'arm': 76,
#  'nestled': 77,
#  'beyond': 78,
#  'canes': 79,
#  'dust': 80,
#  'grabbed': 81,
#  'living': 82,
#  'molly': 83,
#  'stories': 84,
#  'snuggle': 85,
#  'leading': 86,
#  'those': 87,
#  'dreamland': 88,
#  'suitcase': 89,
#  'crystal': 90,
#  'wands': 91,
#  'fly': 92,
#  'nibbles': 93,
#  'bobby': 94,
#  'always': 95,
#  'floppy': 96,
#  'went': 97,
#  'remembered': 98,
#  'families': 99,
#  'sara': 100,
#  'fairies': 101,
#  'arms': 102,
#  'fantastical': 103,
#  'passed': 104,
#  'jimmy': 105,
#  'bad': 106,
#  'journeyed': 107,
#  'mia': 108,
#  'noticed': 109,
#  'ducks': 110,
#  'prayer': 111,
#  'eyes': 112,
#  'lay': 113,
#  'snowy': 114,
#  'comfy': 115,
#  'snuggly': 116,
#  'town': 117,
#  'ingenuity': 118,
#  'awaits': 119,
#  'you': 120,
#  'bigger': 121,
#  "vince's": 122,
#  'park': 123,
#  'nap': 124,
#  'splash': 125,
#  'honey': 126,
#  'falling': 127,
#  'mum': 128,
#  'stick': 129,
#  'willow': 130,
#  'nonetheless': 131,
#  'breeze': 132,
#  'marveling': 133,
#  'spotted': 134,
#  'silent': 135,
#  'caress': 136,
#  'pyjamas': 137,
#  'shampoo': 138,
#  'dad': 139,
#  'married': 140,
#  'pulling': 141,
#  'jack': 142,
#  'god': 143,
#  'byes': 144,
#  'elephant': 145,
#  'his': 146,
#  'beam': 147,
#  'hard': 148,
#  'wispy': 149,
#  'delivered': 150,
#  'matter': 151,
#  'eventually': 152,
#  'nibble': 153,
#  'constellations': 154,
#  'enough': 155,
#  'planets': 156,
#  'ear': 157,
#  'giving': 158,
#  'leave': 159,
#  'throughout': 160,
#  'cats': 161,
#  'sparkled': 162,
#  'pm': 163,
#  'nightfall': 164,
#  'as': 165,
#  'stardust': 166,
#  'felt': 167,
#  'settled': 168,
#  'possibilities': 169,
#  'miss': 170,
#  'companion': 171,
#  'come': 172,
#  'helped': 173,
#  'curtains': 174,
#  'walls': 175,
#  'held': 176,
#  'ocean': 177,
#  'lying': 178,
#  'like': 179,
#  'sarah': 180,
#  'frustration': 181,
#  'adored': 182,
#  'sam': 183,
#  'earth': 184,
#  'jill': 185,
#  'beforehand': 186,
#  'amazement': 187,
#  'believed': 188,
#  'soft': 189,
#  'send': 190,
#  'food': 191,
#  'woods': 192,
#  'than': 193,
#  'heart': 194,
#  'low': 195,
#  'wanted': 196,
#  'kingdom': 197,
#  'enchanted': 198,
#  'pot': 199,
#  'old': 200,
#  'wink': 201,
#  'kinds': 202,
#  'embrace': 203,
#  'tilly': 204,
#  'courageous': 205,
#  'light': 206,
#  'melody': 207,
#  "you'll": 208,
#  'patrick': 209,
#  'asleep': 210,
#  'yellow': 211,
#  'droop': 212,
#  'steep': 213,
#  'meets': 214,
#  'with': 215,
#  'grow': 216,
#  'fox': 217,
#  'makes': 218,
#  'cubs': 219,
#  'spot': 220,
#  'absolutely': 221,
#  'face': 222,
#  'this': 223,
#  'nests': 224,
#  "lucy's": 225,
#  'constantly': 226,
#  'contentedly': 227,
#  'rocked': 228,
#  'discovering': 229,
#  'key': 230,
#  'its': 231,
#  'wall': 232,
#  'much': 233,
#  'inviting': 234,
#  'loud': 235,
#  'ride': 236,
#  'african': 237,
#  'slumber': 238,
#  'needed': 239,
#  'ready': 240,
#  'darkness': 241,
#  'pillow': 242,
#  'greet': 243,
#  'bob': 244,
#  'angel': 245,
#  'store': 246,
#  'relaxed': 247,
#  'loves': 248,
#  'soon': 249,
#  'where': 250,
#  'being': 251,
#  'awaiting': 252,
#  'faith': 253,
#  'by': 254,
#  "sunrise's": 255,
#  'adventures': 256,
#  'through': 257,
#  'heads': 258,
#  'wand': 259,
#  'voice': 260,
#  'firmly': 261,
#  'path': 262,
#  'especially': 263,
#  'campfire': 264,
#  'ground': 265,
#  'replaced': 266,
#  'distant': 267,
#  'tremble': 268,
#  'find': 269,
#  'enjoying': 270,
#  'piles': 271,
#  'starlit': 272,
#  'patterned': 273,
#  'tired': 274,
#  'both': 275,
#  'sue': 276,
#  'swing': 277,
#  'to': 278,
#  'royal': 279,
#  'very': 280,
#  'everywhere': 281,
#  'amazing': 282,
#  'flutter': 283,
#  'goes': 284,
#  'treehouse': 285,
#  'enjoyed': 286,
#  'princesses': 287,
#  'hello': 288,
#  "we'll": 289,
#  'pure': 290,
#  "it's": 291,
#  'armadillo': 292,
#  'yawn': 293,
#  "elsie's": 294,
#  'i': 295,
#  'returned': 296,
#  'doorstep': 297,
#  'beneath': 298,
#  'soundly': 299,
#  'delicious': 300,
#  'stand': 301,
#  'grown': 302,
#  'mischievous': 303,
#  'toys': 304,
#  'twenty': 305,
#  'feet': 306,
#  'galaxies': 307,
#  'live': 308,
#  'scampered': 309,
#  'having': 310,
#  'final': 311,
#  'visiting': 312,
#  'young': 313,
#  'way': 314,
#  'so': 315,
#  'filling': 316,
#  'tallest': 317,
#  'forests': 318,
#  'ever': 319,
#  'during': 320,
#  'danger': 321,
#  'windowsill': 322,
#  'lush': 323,
#  'discovers': 324,
#  'is': 325,
#  'sings': 326,
#  "parents'": 327,
#  'adventurer': 328,
#  'need': 329,
#  'rivers': 330,
#  'cozy': 331,
#  'forget': 332,
#  'pulled': 333,
#  'darigan': 334,
#  'satisfied': 335,
#  'shimmered': 336,
#  "tomorrow's": 337,
#  'paint': 338,
#  'showed': 339,
#  'embark': 340,
#  'warm': 341,
#  'towards': 342,
#  's': 343,
#  'lullaby': 344,
#  'brushing': 345,
#  'furry': 346,
#  'goodbyes': 347,
#  'go': 348,
#  'terrains': 349,
#  'such': 350,
#  'noise': 351,
#  'naps': 352,
#  'along': 353,
#  'earlier': 354,
#  'magical': 355,
#  'clear': 356,
#  'finally': 357,
#  'treasures': 358,
#  'careful': 359,
#  'seeking': 360,
#  'hear': 361,
#  'seen': 362,
#  'white': 363,
#  'explored': 364,
#  'trouble': 365,
#  'skipped': 366,
#  'again': 367,
#  'stumbled': 368,
#  'guard': 369,
#  "mom's": 370,
#  'wherever': 371,
#  'surprised': 372,
#  'comforter': 373,
#  'illuminating': 374,
#  "abigail's": 375,
#  'did': 376,
#  'feeling': 377,
#  'decided': 378,
#  'gift': 379,
#  'sasquatch': 380,
#  'flash': 381,
#  'ruby': 382,
#  'thought': 383,
#  'curiosity': 384,
#  'dreamer': 385,
#  'stared': 386,
#  'settling': 387,
#  'hillside': 388,
#  'opened': 389,
#  'swooped': 390,
#  'rabbits': 391,
#  'slowly': 392,
#  'forward': 393,
#  'wise': 394,
#  'belinda': 395,
#  'gone': 396,
#  'glitter': 397,
#  'car': 398,
#  'fell': 399,
#  'shake': 400,
#  'freshly': 401,
#  "daisy's": 402,
#  'discoveries': 403,
#  'tapestry': 404,
#  'parents': 405,
#  'floated': 406,
#  'able': 407,
#  'creatures': 408,
#  'blessed': 409,
#  'maddie': 410,
#  'doors': 411,
#  'take': 412,
#  'alex': 413,
#  'castle': 414,
#  'charming': 415,
#  'sorts': 416,
#  'goodnight': 417,
#  'morning': 418,
#  'getting': 419,
#  'kind': 420,
#  'turn': 421,
#  'soared': 422,
#  "emily's": 423,
#  'crickets': 424,
#  'bears': 425,
#  'night': 426,
#  'forehead': 427,
#  'awhile': 428,
#  'animals': 429,
#  'feathered': 430,
#  'ellie': 431,
#  'tire': 432,
#  'drive': 433,
#  'elf': 434,
#  'hop': 435,
#  'looked': 436,
#  'cave': 437,
#  'snuggling': 438,
#  'well': 439,
#  'nibbled': 440,
#  'curves': 441,
#  'patch': 442,
#  'saying': 443,
#  'ball': 444,
#  'approached': 445,
#  'colorful': 446,
#  'know': 447,
#  'all': 448,
#  'snuggles': 449,
#  'climbing': 450,
#  'treasure': 451,
#  'dragon': 452,
#  'village': 453,
#  'since': 454,
#  'style': 455,
#  'galaxy': 456,
#  'hat': 457,
#  'fish': 458,
#  'happily': 459,
#  'plucked': 460,
#  'blink': 461,
#  'nighttime': 462,
#  'millie': 463,
#  'sing': 464,
#  'friend': 465,
#  'brushed': 466,
#  'comfort': 467,
#  'every': 468,
#  'hopped': 469,
#  'single': 470,
#  'sky': 471,
#  'refreshed': 472,
#  'excited': 473,
#  "kings'": 474,
#  'nothing': 475,
#  'brighter': 476,
#  'forest': 477,
#  'dolphins': 478,
#  'joy': 479,
#  'danced': 480,
#  'pond': 481,
#  'play': 482,
#  'emmy': 483,
#  'journey': 484,
#  'plenty': 485,
#  'waved': 486,
#  'liza': 487,
#  'sweetheart': 488,
#  'wave': 489,
#  'prince': 490,
#  'burrow': 491,
#  'burrows': 492,
#  'log': 493,
#  'huge': 494,
#  'reminder': 495,
#  'made': 496,
#  'wildest': 497,
#  'silly': 498,
#  'bored': 499,
#  'anew': 500,
#  'entranced': 501,
#  'eagle': 502,
#  'arrives': 503,
#  'climbed': 504,
#  'hannah': 505,
#  'mesmerized': 506,
#  'star': 507,
#  'family': 508,
#  'benny': 509,
#  'he': 510,
#  'imagining': 511,
#  'snug': 512,
#  'walked': 513,
#  'guardian': 514,
#  'disappointed': 515,
#  "friend's": 516,
#  'flapping': 517,
#  'cuddle': 518,
#  'have': 519,
#  'other': 520,
#  'were': 521,
#  'anticipation': 522,
#  'joey': 523,
#  'cabin': 524,
#  'music': 525,
#  'even': 526,
#  'knew': 527,
#  'spending': 528,
#  'discover': 529,
#  'highest': 530,
#  'admired': 531,
#  'magic': 532,
#  'soaring': 533,
#  'turned': 534,
#  'roof': 535,
#  'return': 536,
#  'wondered': 537,
#  'wonders': 538,
#  'gaze': 539,
#  'setting': 540,
#  'biggest': 541,
#  'filled': 542,
#  'steady': 543,
#  'diamonds': 544,
#  'stuffed': 545,
#  'pat': 546,
#  'taking': 547,
#  'door': 548,
#  'sasha': 549,
#  'raced': 550,
#  'bush': 551,
#  'protection': 552,
#  "chrissy's": 553,
#  'advice': 554,
#  'jungles': 555,
#  'tranquillity': 556,
#  'package': 557,
#  'good': 558,
#  'once': 559,
#  'high': 560,
#  'odd': 561,
#  'swimming': 562,
#  'ending': 563,
#  'leaves': 564,
#  'interesting': 565,
#  'glowing': 566,
#  'playful': 567,
#  'going': 568,
#  'dog': 569,
#  'changing': 570,
#  'jar': 571,
#  'moments': 572,
#  'returning': 573,
#  'side': 574,
#  'nest': 575,
#  'worlds': 576,
#  'presence': 577,
#  'grab': 578,
#  'hug': 579,
#  'fresh': 580,
#  'dreamt': 581,
#  'traveler': 582,
#  'cheek': 583,
#  'talking': 584,
#  'shining': 585,
#  'toward': 586,
#  'found': 587,
#  'scared': 588,
#  'request': 589,
#  'himself': 590,
#  'city': 591,
#  'aliens': 592,
#  'them': 593,
#  "castle's": 594,
#  'investigate': 595,
#  'giggling': 596,
#  'bunnies': 597,
#  "ruby's": 598,
#  'darken': 599,
#  'mouse': 600,
#  'stopped': 601,
#  'across': 602,
#  'hide': 603,
#  'banks': 604,
#  'universe': 605,
#  'wonder': 606,
#  'nightly': 607,
#  "didn't": 608,
#  'foot': 609,
#  'now': 610,
#  'sadie': 611,
#  'sending': 612,
#  'kids': 613,
#  'liam': 614,
#  'grew': 615,
#  'gem': 616,
#  'owl': 617,
#  'notes': 618,
#  'adventure': 619,
#  'fun': 620,
#  'top': 621,
#  'sometimes': 622,
#  'alright': 623,
#  'down': 624,
#  'canary': 625,
#  'milk': 626,
#  'name': 627,
#  'feel': 628,
#  'golden': 629,
#  'stuck': 630,
#  'get': 631,
#  'bouncing': 632,
#  'rode': 633,
#  'shelter': 634,
#  'jumped': 635,
#  'alina': 636,
#  'beddy': 637,
#  'kiss': 638,
#  'glimmering': 639,
#  'kitten': 640,
#  'curious': 641,
#  'stay': 642,
#  'took': 643,
#  'far': 644,
#  'gently': 645,
#  'moving': 646,
#  'sent': 647,
#  'bid': 648,
#  'treats': 649,
#  'around': 650,
#  'sweetest': 651,
#  'touched': 652,
#  'it': 653,
#  'told': 654,
#  'patrolling': 655,
#  'little': 656,
#  'suddenly': 657,
#  'gold': 658,
#  'exploring': 659,
#  'knowing': 660,
#  'eagerly': 661,
#  'looming': 662,
#  'one': 663,
#  "wasn't": 664,
#  'time': 665,
#  'passes': 666,
#  'evermore': 667,
#  'thankful': 668,
#  'games': 669,
#  'discussed': 670,
#  'saw': 671,
#  "sara's": 672,
#  'lit': 673,
#  'dreaming': 674,
#  'size': 675,
#  'knowledge': 676,
#  'rose': 677,
#  'hidden': 678,
#  'herself': 679,
#  'elaine': 680,
#  'curled': 681,
#  'waddle': 682,
#  'happen': 683,
#  'curiously': 684,
#  'adventurers': 685,
#  'hares': 686,
#  'bird': 687,
#  'places': 688,
#  'sun': 689,
#  "unicorn's": 690,
#  'watched': 691,
#  'emily': 692,
#  'alone': 693,
#  'search': 694,
#  'vivid': 695,
#  'abigail': 696,
#  'least': 697,
#  'flew': 698,
#  'air': 699,
#  'onto': 700,
#  'protecting': 701,
#  'bed': 702,
#  'power': 703,
#  'imaginable': 704,
#  'horizon': 705,
#  'heading': 706,
#  'reached': 707,
#  'daring': 708,
#  'amazed': 709,
#  'carefully': 710,
#  'almost': 711,
#  'shared': 712,
#  'scurrying': 713,
#  'kept': 714,
#  'making': 715,
#  'below': 716,
#  'leo': 717,
#  'ritual': 718,
#  'unicorn': 719,
#  'girl': 720,
#  'quickly': 721,
#  'grandpa': 722,
#  'hunt': 723,
#  'listens': 724,
#  'dinner': 725,
#  'peek': 726,
#  'mushroom': 727,
#  'jane': 728,
#  'landed': 729,
#  'not': 730,
#  'disappeared': 731,
#  'delight': 732,
#  'extraordinary': 733,
#  'answered': 734,
#  'snack': 735,
#  'highways': 736,
#  'promised': 737,
#  'chat': 738,
#  'lives': 739,
#  'parted': 740,
#  'shoulder': 741,
#  'of': 742,
#  'off': 743,
#  'materialized': 744,
#  'sleeping': 745,
#  'explore': 746,
#  'snow': 747,
#  'wrong': 748,
#  'horse': 749,
#  'grandchildren': 750,
#  'peered': 751,
#  'present': 752,
#  'ventured': 753,
#  'reminded': 754,
#  "she'd": 755,
#  'musician': 756,
#  'believe': 757,
#  'pirate': 758,
#  'their': 759,
#  'owls': 760,
#  'goodnights': 761,
#  'lakes': 762,
#  'starlight': 763,
#  'gentle': 764,
#  'story': 765,
#  'charlie': 766,
#  'searching': 767,
#  'whispered': 768,
#  'bridge': 769,
#  'said': 770,
#  'deep': 771,
#  'yawned': 772,
#  'hooting': 773,
#  'river': 774,
#  'sweet': 775,
#  'pile': 776,
#  'met': 777,
#  'bricks': 778,
#  'humming': 779,
#  'fortune': 780,
#  'then': 781,
#  'sit': 782,
#  'him': 783,
#  'daisy': 784,
#  'there': 785,
#  "sam's": 786,
#  'jasper': 787,
#  'claire': 788,
#  'tasty': 789,
#  'alike': 790,
#  'moonlight': 791,
#  'beauty': 792,
#  'ended': 793,
#  'back': 794,
#  'swam': 795,
#  'liked': 796,
#  'above': 797,
#  'monsters': 798,
#  'quests': 799,
#  'vanished': 800,
#  'sleep': 801,
#  'singing': 802,
#  'puppy': 803,
#  'endless': 804,
#  'peeked': 805,
#  'forgotten': 806,
#  'slow': 807,
#  'cup': 808,
#  'open': 809,
#  'rippling': 810,
#  'same': 811,
#  'sunlight': 812,
#  'heard': 813,
#  'dashing': 814,
#  'braver': 815,
#  'continued': 816,
#  'peaceful': 817,
#  'yet': 818,
#  'nora': 819,
#  'different': 820,
#  'lifting': 821,
#  'upon': 822,
#  'imagine': 823,
#  'from': 824,
#  'covers': 825,
#  'mother': 826,
#  'chrissy': 827,
#  'friends': 828,
#  'smiled': 829,
#  'trees': 830,
#  'beginning': 831,
#  'woven': 832,
#  'purple': 833,
#  'anymore': 834,
#  'pet': 835,
#  'soar': 836,
#  'hearing': 837,
#  'anything': 838,
#  'balcony': 839,
#  'boat': 840,
#  'lions': 841,
#  'timid': 842,
#  'got': 843,
#  "jimmy'd": 844,
#  'houses': 845,
#  'lonely': 846,
#  'listen': 847,
#  'd': 848,
#  'garden': 849,
#  'end': 850,
#  'pink': 851,
#  'cuddles': 852,
#  'wrap': 853,
#  'winding': 854,
#  'mabel': 855,
#  'memories': 856,
#  'luna': 857,
#  'begged': 858,
#  'prayed': 859,
#  'last': 860,
#  'despite': 861,
#  "max's": 862,
#  'ollie': 863,
#  'meet': 864,
#  'game': 865,
#  'island': 866,
#  'say': 867,
#  'glee': 868,
#  'wide': 869,
#  'cities': 870,
#  'backyard': 871,
#  'watch': 872,
#  'fruits': 873,
#  'surprise': 874,
#  'darker': 875,
#  'nature': 876,
#  'flowers': 877,
#  'imagined': 878,
#  'was': 879,
#  'unafraid': 880,
#  'woke': 881,
#  'anne': 882,
#  'sprinkled': 883,
#  'eye': 884,
#  'do': 885,
#  'bowl': 886,
#  'small': 887,
#  'colour': 888,
#  'favourite': 889,
#  'toe': 890,
#  'gasp': 891,
#  "lily's": 892,
#  'adorable': 893,
#  'whispering': 894,
#  'tightly': 895,
#  'boy': 896,
#  'snails': 897,
#  'bouquet': 898,
#  'ella': 899,
#  'hopes': 900,
#  'quiet': 901,
#  'although': 902,
#  'a': 903,
#  'up': 904,
#  'gifted': 905,
#  'annie': 906,
#  'opens': 907,
#  'fast': 908,
#  'jenny': 909,
#  'rush': 910,
#  'place': 911,
#  'until': 912,
#  'pup': 913,
#  'space': 914,
#  'teeth': 915,
#  'an': 916,
#  'hum': 917,
#  'mountain': 918,
#  'lived': 919,
#  'two': 920,
#  'surprises': 921,
#  'figured': 922,
#  'wings': 923,
#  'silvery': 924,
#  'seek': 925,
#  'no': 926,
#  'tight': 927,
#  'wildflowers': 928,
#  'including': 929,
#  'best': 930,
#  'special': 931,
#  'foxes': 932,
#  'beside': 933,
#  'momma': 934,
#  'mug': 935,
#  'room': 936,
#  'eating': 937,
#  'spider': 938,
#  'followed': 939,
#  'prayers': 940,
#  'fairytale': 941,
#  'meeting': 942,
#  'brightest': 943,
#  'meadow': 944,
#  'bell': 945,
#  'coming': 946,
#  'pick': 947,
#  'leads': 948,
#  'after': 949,
#  'awe': 950,
#  'mommy': 951,
#  'sammy': 952,
#  'headed': 953,
#  'lola': 954,
#  'gathered': 955,
#  'evening': 956,
#  'mark': 957,
#  'right': 958,
#  'offered': 959,
#  'visited': 960,
#  'sparkling': 961,
#  'jumping': 962,
#  'sheep': 963,
#  'on': 964,
#  'swim': 965,
#  'be': 966,
#  'learned': 967,
#  'next': 968,
#  'kissed': 969,
#  'ahead': 970,
#  'she': 971,
#  'hopping': 972,
#  'showing': 973,
#  'bring': 974,
#  'drooped': 975,
#  'moon': 976,
#  'masterful': 977,
#  'whenever': 978,
#  'pinecones': 979,
#  'miraculously': 980,
#  "lola's": 981,
#  "anna's": 982,
#  'spent': 983,
#  'dancing': 984,
#  'toby': 985,
#  'buster': 986,
#  'became': 987,
#  'jewels': 988,
#  'join': 989,
#  'flute': 990,
#  'perch': 991,
#  'birds': 992,
#  'might': 993,
#  'that': 994,
#  'transparent': 995,
#  'few': 996,
#  'water': 997,
#  'recounting': 998,
#  'travelled': 999,
#  ...}

# %%
#Now we build the indexed vocabulary
indexed_corpus = [wordToId[word] for word in tokens]

# %%
print(indexed_corpus[:10])
# Out:
# [1519, 1331, 1318, 1174, 1519, 426, 471, 165, 656, 1046]

# %% [markdown]
# **Now we generate the sample pairs:**

# %%
def pairGeneration(corpus, window):
    pairs=[]
    for i,target in enumerate(corpus):
        start = max(0, i - window)
        end = min(len(corpus), i + window + 1)
        for j in range(start,end):
            if i!=j:
                context = corpus[j]
                pairs.append((target, context))
    return pairs

# %%
window_size = 2
pairs = pairGeneration(indexed_corpus, window_size)

# %%
print(pairs[:10]) #(target_id, context_id)
# Out:
# [(1519, 1331), (1519, 1318), (1331, 1519), (1331, 1318), (1331, 1174), (1318, 1519), (1318, 1331), (1318, 1174), (1318, 1519), (1174, 1331)]

# %% [markdown]
# We finish the first task! We save the result for the next notebook

# %%
import pickle

with open("word2id.pkl", "wb") as f:
    pickle.dump(wordToId, f)

with open("id2word.pkl", "wb") as f:
    pickle.dump(idToWord, f)

with open("corpus.pkl", "wb") as f:
    pickle.dump(indexed_corpus, f)

with open("pairs.pkl", "wb") as f:
    pickle.dump(pairs, f)
